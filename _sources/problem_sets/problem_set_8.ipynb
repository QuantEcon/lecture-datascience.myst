# %% [markdown]
# # Problem Set 8
#
# In this problem set, your goal is to train a model to best predict
# log housing values. The criteria for best prediction is mean squared error.
# The file ahs.csv contains data from the [American Housing
# Survey](https://www.census.gov/programs-surveys/ahs.html) . Your predictive model will be
# graded based on another evaluation sample from the same survey.
# You should create a function that returns the predictions of your model
# when given an identically-formatted csv file with all the same variables.
# (Your function should not refit your model on the evaluation sample.)
# In addition, answer the questions below.
#
# ## Additional Rules
#
# You may not use additional data from the American Housing Survey to
# fit your model. You may use data from other sources (although this
# is not necessary to receive a good grade). You may use methods not
# covered in this course (although this is also not necessary to receive
# a good grade).

# %%
import pandas as pd
import numpy as np
from sklearn import (
    linear_model, metrics, neural_network, pipeline,
    model_selection, tree
)
from sklearn.ensemble import RandomForestRegressor
# load data
ahs = pd.read_csv("https://datascience.quantecon.org/assets/data/ahs-train.csv")
ahs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Columns: 151 entries, LOGVALUE to NOWIRE
# dtypes: float64(13), int64(138)
# memory usage: 2.3 MB

# %%
# dataframe of variable descriptions
ahs_doc = pd.read_csv("https://datascience.quantecon.org/assets/data/ahs-doc.csv", encoding="latin1")
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'max_colwidth', -1):
    display(ahs_doc[["Variable","Question","Description","Associated.Response.Codes"]])
# Out:
#        Variable  \
# 0    NEWC
# 1    METRO
# 2    METRO3
# 3    REGION
# 4    CONDO
# 5    OWNLOT
# 6    NUNITS
# 7    TYPE
# 8    NUNIT2
# 9    BUILT
# 10   BUSPER
# 11   DIRAC
# 12   DRSHOP
# 13   ELEV
# 14   ELEVWK
# 15   EXCLUS
# 16   OTBUP
# 17   SHARAT
# 18   SHARFR
# 19   GARAGE
# 20   PORCH
# 21   LOT
# 22   EBAR
# 23   MOBILTYP
# 24   CLIMB
# 25   INCP
# 26   DINING
# 27   LAUNDY
# 28   LIVING
# 29   CELLAR
# 30   DENS
# 31   OTHFN
# 32   FLOORS
# 33   UNITSF
# 34   KITCH
# 35   ROOMS
# 36   BEDRMS
# 37   FAMRM
# 38   RECRM
# 39   BATHS
# 40   HALFB
# 41   OTHRUN
# 42   KITCHEN
# 43   KEXCLU
# 44   BSINK
# 45   TOILET
# 46   FPLWK
# 47   EHEATUT
# 48   FLOT
# 49   FPINS
# 50   FRPL
# 51   FRPLI
# 52   STEAM
# 53   WINTERELSP
# 54   WINTERKESP
# 55   WINTERNONE
# 56   WINTEROVEN
# 57   WINTERWOOD
# 58   AIR
# 59   AIRSYS
# 60   EAIRC
# 61   ECNTAIR
# 62   NUMAIR
# 63   OARSYS
# 64   SEWDUS
# 65   WATER
# 66   SEWDIS
# 67   SEWDISTP
# 68   REFR
# 69   DISH
# 70   SINK
# 71   WASH
# 72   DRY
# 73   BURNER
# 74   COOK
# 75   DISPL
# 76   EDISHWR
# 77   EDRYER
# 78   EFRIDGE
# 79   ENOEAPP
# 80   EOTEAPP
# 81   ETRSHCP
# 82   EWASHR
# 83   OVEN
# 84   PHONE
# 85   TRASH
# 86   NOWIRE
# 87   PLUGS
# 88   IFBLOW
# 89   NUMBLOW
# 90   FREEZE
# 91   IFCOLD
# 92   NUMCOLD
# 93   WHYCD1
# 94   WHYCD2
# 95   WHYCD3
# 96   WHYCD4
# 97   WHYCD5
# 98   OTHCLD
# 99   IFTLT
# 100  NUMTLT
# 101  IFDRY
# 102  NUMDRY
# 103  HOTPIP
# 104  IFSEW
# 105  NUMSEW
# 106  PLUMB
# 107  PUBSEW
# 108  EVROD
# 109  EROACH
# 110  M12ROD
# 111  M12ROACH
# 112  MICE
# 113  RATS
# 114  RATFREQ
# 115  ROACHFRQ
# 116  NOTSUR
# 117  ECRUMB
# 118  EHOLER
# 119  EMISSR
# 120  ESAGR
# 121  EMISSW
# 122  ESLOPW
# 123  EBOARD
# 124  EBROKE
# 125  HOLES
# 126  CRACKS
# 127  LEAK
# 128  RLEAK
# 129  BLEAK
# 130  WLEAK
# 131  OTLEAK
# 132  ILEAK
# 133  PLEAK
# 134  PILEAK
# 135  WTRHRL
# 136  NLEAK1
# 137  NLEAK2
# 138  ZADEQ
# 139  EGOOD
# 140  FRSTOC
# 141  WHNGET
# 142  PREOCC
# 143  HOWH
# 144  WELL
# 145  WELDUS
# 146  WELLDIS
# 147  WELLDIS2
# 148  WATERS
# 149  WATERD
#
#                                                                                                                                                                                                                                                Question  \
# 0    This is a recoded variable based on the month and year the unit was built and the month and year of the interview.
# 1    This recode specifies all central cities in each MSA.
# 2    NaN
# 3    NaN
# 4    Is this unit part of a condominium?
# 5    See User Notes
# 6    How many apartments are in the building?
# 7    Is this unit (or address) a house, an apartment, a manufactured/mobile home, or some other type of residence?
# 8    These living quarters in a -
# 9    Year this housing unit was built. (If respondent replies DK or is uncertain, probe: Do you know what decade, such as the 80's, 70's, 60's or some other decade?)
# 10   How many rooms, if any, are used both as business space and for personal use?
# 11   And, how many offices used for business have direct access to the outside?
# 12   Is there a medical or dental office or any commercial establishment on the property?
# 13   Is there a working passenger elevator to your floor? (COUNT FREIGHT ELEVATORS ALSO MEANT TO BE USED BY PASSENGERS)
# 14   NaN
# 15   You mentioned having some offices in your home. How many of these offices are used exclusively for business?
# 16   Is there any other building on the property for people to live in--either occupied or vacant?
# 17   Does this housing unit share an attic or basement with the housing unit next door?
# 18   Does this housing unit share a furnace or boiler with the housing unit next door?
# 19   Is a garage or carport included with this unit?
# 20   Does this unit have a porch, deck, balcony, or patio?
# 21   About how large is the lot? *** INCLUDE ALL CONNECTING LAND THAT IS OWNED OR THAT IS RENTED WITH THE HOME*** *** IF OVER 1 ACRE, DROP ANY FRACTIONS, DON'T ROUND UP *** *** IF UNDER 1 ACRE, CONVERT TO APPROXIMATE SQUARE FEET *** One eight
# 22   Are any of the windows in any rooms covered with metal bars?
# 23   NaN
# 24   How many stories are there from the main entrance of the building to the main entrance of this apartment?
# 25   Is a driveway/lot/parking area off the street provided?
# 26   How many separate dining rooms?
# 27   How many laundry, utility, or pantry rooms?
# 28   How many living rooms?
# 29   Is this house built-
# 30   How many dens or libraries?
# 31   How many other finished rooms?
# 32   How many stories are there in this building ?
# 33   Thinking about all the rooms you mentioned earlier, as well as the hallways and entry ways in this housing unit, about how many square feet is that? (Include: Finished attics. Exclude: Unfinished attics, carports, and attached garages. Al
# 34   How many kitchens?
# 35   NaN
# 36   Recoded sum of BEDRMS1 through BEDRMS5
# 37   How many family rooms, great rooms, or TV rooms?
# 38   How many recreation rooms?
# 39   Recoded sum of BATHS1 through BATHS5
# 40   Recoded sum of HALFB1 through HALFB5
# 41   Recoded sum of OTHUN1 through OTHUN5
# 42   To have complete kitchen facilities, the unit must meet the following conditions: Single unit housing units: must have a sink, refrigerator, and (range, cookstove, microwave, or built-in cooking burners) in the kitchen Multiunit (NUNIT2 = 3)
# 43   Are these kitchen facilities for your household's use only/only for the use of future tenants/owners?
# 44   Does this full bath contain a bathroom sink? Does this housing unit have a bathroom sink?
# 45   Does this full bath contain a flush toilet? Does this housing unit have a flush toilet?
# 46   Does this housing unit have a useable fireplace?
# 47   Are any of these appliances energy star rated?
# 48   Is it VENTED to the outside through a chimney, flue, or pipes OR is it UNVENTED?
# 49   Does it have inserts, that is, equipment designed to circulate more heat into the room?
# 50   Does it have inserts, that is, equipment designed to circulate more heat into the room?
# 51   Does it have inserts, that is, equipment designed to circulate more heat into the room?
# 52   What OTHER kinds of working heating equipment does this housing unit HAVE or USE?
# 53   Have you ever used any of the following to heat this home during the winter months?
# 54   Have you ever used any of the following to heat this home during the winter months?
# 55   Have you ever used any of the following to heat this home during the winter months?
# 56   Have you ever used any of the following to heat this home during the winter months?
# 57   Have you ever used any of the following to heat this home during the winter months?
# 58   Do you (also) use any room air conditioners? Do other residents use any room air conditioners? Does the housing unit have any room air conditioners?
# 59   Does this heat pump/heating equipment provide air conditioning for this home? Does this housing unit have central air conditioning?
# 60   Are any of these appliances energy star rated?
# 61   Are any of these appliances energy star rated?
# 62   How Many?
# 63   Besides this heat pump, does this home have another CENTRAL air conditioning system? Does this home have ANOTHER CENTRAL air conditioning system?
# 64   How many homes are connected to the sewage system?
# 65   Does most of the water for this housing unit come from a water system, either public or private, from an individual well, or from some other source?
# 66   What means of sewage disposal does this housing unit have?
# 67   What type of sewage disposal system do you have?
# 68   Does this housing unit have a refrigerator that is in working order? (Exclude ice boxes.)
# 69   Recode created from DISHQ, APPLWK, DISHWK, DISHFX
# 70   Does this housing unit have a kitchen sink?
# 71   Recode created from WASHQ, APPLWK, WASHWK, WASHFX
# 72   Recode created from DRYQ, APPLWK, DRYWK, DRYFX
# 73   Does this housing unit have any built-in cooking burners that are in working order?
# 74   Does this housing unit have some type of cooking stove, or a range with an oven--one that is in working order?
# 75   Recode created from DISPLQ, APPLWK, DISPLWK, DISPLFX
# 76   Are any of these appliances energy star rated?
# 77   Are any of these appliances energy star rated?
# 78   Are any of these appliances energy star rated?
# 79   Are any of these appliances energy star rated?
# 80   Are any of these appliances energy star rated?
# 81   Are any of these appliances energy star rated?
# 82   Are any of these appliances energy star rated?
# 83   Does this housing unit have a microwave oven that is in working order?
# 84   This recode indicates whether or not a telephone is in the housing unit. If there is no telephone in the unit, then the recode indicates whether or not there is a telephone available somewhere for the household's use
# 85   Recode created from TRASHQ, APPLWK, TRASHWK, TRASHFX
# 86   Is all the electrical wiring in the finished areas of this unit either concealed inside walls or under protective metal or plastic coverings?
# 87   Does every room have an electrical outlet or wall plug that works?
# 88   Have any fuses blown or circuit breakers tripped in your home?
# 89   How many times fuses blown or breakers tripped?
# 90   Last winter, for any reason, was your housing unit so cold for 24 hours or more that it was uncomfortable?
# 91   Was that because the MAIN heating equipment broke down?
# 92   How many times did main heating equipment break down for 6 hours or more?
# 93   What was the reason?
# 94   What was the reason?
# 95   What was the reason?
# 96   What was the reason?
# 97   What was the reason?
# 98   Was it cold for any other reason?
# 99   Was there any time in last 3 months when the toilet BROKEN, or STOPPED UP, or otherwise NOT WORKING, so you COULDN'T USE it? Did that happen at all WITHIN THE PAST THREE MONTHS, that is, since 3 months ago (date)?
# 100  And how many of those times toilet not working for SIX HOURS or MORE?
# 101  Was your home ever COMPLETELY without running water
# 102  How many times was it not available for 6 hours or more?
# 103  Does this full bath contain both hot and cold water? Does this housing unit have both hot and cold water?
# 104  Did the sewage system break down in your home -- that is, since last interview?
# 105  How many of these breakdowns lasted 6 hours or more?
# 106  To have complete plumbing facilities, the unit must have exclusive use of hot and cold running water, a toilet, and a bathtub/shower in the bathroom. Lack of any of these items or lack of exclusive use means the unit does not have complete p
# 107  Is this housing unit connected to a public sewer?
# 108  Have you ever seen signs of mice or rats INSIDE your housing unit ? (EXCLUDE RATS/MICE KEPT AS PETS OR SNAKE FOOD OR OTHERWISE DELIBERATELY BROUGHT INSIDE)
# 109  Have you ever seen signs of live or dead cockroaches or cockroach feces INSIDE your living quarters?
# 110  Was that within the past 12 months -- that is, since 12 months ago (date)?
# 111  Was that within the past 12 months -- that is, since 12 months ago (date)?
# 112  Was it a rat, a mouse, or aren't you sure what it was?
# 113  Was it a rat, a mouse, or aren't you sure what it was?
# 114  How often have you seen any evidence of mice or rats in your home since 12 months ago (date)? Would you say it was daily, weekly, monthly, or a few times?
# 115  How often have you seen any live or dead cockroaches or cockroach feces INSIDE your home since 12 months ago (date)? Would you say it was daily, weekly, monthly, or a few times?
# 116  Was it a rat, a mouse, or aren't you sure what it was?
# 117  Are there holes or open cracks or crumbling in the foundation of this housing unit--that is, in the base on which the housing unit stands? (Do not count holes made for ventilation)
# 118  Does the roof have any holes?
# 119  The next questions are about the CONDITION of the outside of this housing unit. Does the roof have missing shingles or other missing roofing materials? (Do not count gutters or downspouts)
# 120  Does the roof's surface sag or appear uneven?
# 121  Do the outside walls have any missing siding, bricks, or other missing wall materials?
# 122  Do the outside walls slope, lean, buckle or slant?
# 123  Are any of the windows in this housing unit boarded up?
# 124  Are any of the windows in this housing unit broken?
# 125  How about the floors in this housing unit Are any holes in the floors big enough for someone to catch their foot on? (ABOUT 4 INCHES ACROSS ABOUT THE HEIGHT OF A SOUP CAN)
# 126  People sometimes have problems with cracks or holes in their home's floors, walls, or ceilings - not little hairline cracks or nail holes, but OPEN cracks or holes. In the INSIDE walls or ceilings of this housing unit, are there any OPEN HOL
# 127  These next questions are about water leaks - either from OUTSIDE your housing unit or from INSIDE. While you have been living here, did water ever leak INTO your housing unit DIRECTLY FROM THE OUTSIDE -- for example, through the roof, outside
# 128  Did the water come in from the --
# 129  Did the water come in from the --
# 130  Did the water come in from the --
# 131  Did the water come in from the --
# 132  Now about water leaks from INSIDE. Since you lived here, did water leak in -- from broken pipes or water heaters, backed up plumbing, or other equipment failure inside the unit? Did any inside water leaks happen within the past 12 months --
# 133  Where did the water come from?
# 134  Where did the water come from?
# 135  Where did the water come from?
# 136  Where did the water come from?
# 137  Where did the water come from?
# 138  If the unit meets just one of the following conditions: Unit has less than 2 full bathrooms (BATHS < 2) and the unit has at least one of the following: Unit does not have hot and cold running water (HOTPIP='2')
# 139  NaN
# 140  Were you the first occupant to occupy this home or did someone else live here before you did?
# 141  When did this household buy/obtain/receive the unit? (IF LAND AND BUILDING BOUGHT AT DIFFERENT TIMES, BUILDING ONLY)
# 142  Did you receive the home as a gift or inheritance or did you purchase it?
# 143  On a scale of 1 to 10, how would you rate your unit as a place to live?
# 144  Is the well drilled or dug?
# 145  How many homes does the water source serve?
# 146  Since you've occupied your home, has the well ever been disinfected?
# 147  Have you been advised by health authorities to disinfect the well?
# 148  In your opinion, is the water from this source safe for cooking and drinking?
# 149  Where do you get your water for drinking?
#
#                                                      Description  \
# 0    New construction in last 4 years
# 1    Multiple central cities/suburban status within metro areas
# 2    Central city / suburban status
# 3    Census region
# 4    Flag indicating unit is a condominium
# 5    Flag indicating owner owns the lot
# 6    Number of units in building
# 7    Housing unit type
# 8    Are these living quarters in a
# 9    Year unit was built
# 10   # rooms used for business/personal use
# 11   Number of offices having direct access
# 12   Medical office/community store on property
# 13   Working passenger elevator
# 14   At least one elevator in working order
# 15   Number offices used exclusively for business
# 16   Other building on property used as living quarters
# 17   Unit shares attic or basement
# 18   Unit shares furnace or boiler
# 19   Flag indicating unit has a garage or carport
# 20   Flag indicating unit has porch or deck or balcony or patio
# 21   Square footage of lot
# 22   Windows covered with metal bars
# 23   Manufactured/mobile home type
# 24   Number of floors from main entrance to apartment
# 25   Offstreet parking included
# 26   Number of dining rooms in unit
# 27   Number of laundry or utility rooms in unit
# 28   Number of living rooms in unit
# 29   Unit has a basement
# 30   Number of dens or libraries in unit
# 31   Number of other finished rooms in unit
# 32   Number of floors within the unit
# 33   Square footage of unit
# 34   Number of kitchens in unit
# 35   Number of rooms in unit
# 36   Number of bedrooms in unit
# 37   Number of family rooms, great rooms, or TV rooms in unit
# 38   Number of recreation rooms in unit
# 39   Number of full bathrooms in unit
# 40   Number of half bathrooms in unit
# 41   Number of other unfinished rooms in unit
# 42   Complete kitchen facilities in unit
# 43   Kitchen facilities for household use only
# 44   Unit has a bathroom sink
# 45   Unit has a flush toilet
# 46   Unit has useable fireplace
# 47   Energy star rated heating equipment
# 48   Heating equipment vented to outside
# 49   Fireplace has inserts
# 50   Fireplace does not have inserts
# 51   Fireplace has inserts
# 52   Steam system used as supplemental heating equipment
# 53   Electric space heater used during winter months
# 54   Kerosene space heater used during winter months
# 55   No use of any other modes to heat unit during winter months
# 56   Gas oven with an open door used during winter months
# 57   Outdoor wood fire boiler used during winter months
# 58   Room air conditioner
# 59   Central air conditioner
# 60   Energy star rated room air conditioner
# 61   Energy star rated central air conditioner
# 62   Number of room air conditioners
# 63   Unit has another central a/c system
# 64   Number of units connected to sewage system
# 65   Source of water for unit
# 66   Type of sewage disposal
# 67   Type of septic tank or cesspool sewage disposal system
# 68   Unit has a working refrigerator
# 69   Unit has working dishwasher
# 70   Unit has kitchen sink
# 71   Unit has a working washing machine
# 72   Unit has working clothes dryer
# 73   Unit has working built-in cooking burners
# 74   Unit has working cookstove or range/oven
# 75   Unit has working garbage disposal
# 76   Energy star rated dishwasher
# 77   Energy star rated clothes dryer
# 78   Energy star rated refrigerator
# 79   No energy star rated appliances
# 80   Unit has another type of energy star rated appliance
# 81   Energy star rated built-in trash compactor
# 82   Energy star rated washing machine
# 83   Unit has a working microwave oven
# 84   Telephone available for use
# 85   Unit has working built-in trash compactor
# 86   Flag indicating electrical wiring concealed by walls
# 87   Flag indicating every room has working electrical plug
# 88   Fuses blown or circuit breakers tripped
# 89   # times fuses blown or breakers tripped
# 90   Unit cold for 24+ hrs was uncomfortable
# 91   Main heating equipment broke down
# 92   # times main heating equipment broke down
# 93   Unit cold due to utility interruption
# 94   Unit cold due to inadequate heating capacity
# 95   Unit cold due to inadequate insulation
# 96   Unit cold due to cost of heating
# 97   Unit cold because of some other reason
# 98   Unit cold for some other reason
# 99   Any toilet breakdowns in last 3 months
# 100  Number of toilet breakdowns 6 hours or more
# 101  Unit completely without running water
# 102  # times completely without running water
# 103  Unit has hot & cold running water
# 104  Sewage system broke down
# ...
# 113  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported
# 114  1: Daily||2: Weekly||3: Monthly||4: A few times||B or -6: Not applicable
# 115  1: Daily||2: Weekly||3: Monthly||4: A few times||B or -6: Not applicable
# 116  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported
# 117  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 118  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 119  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 120  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 121  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 122  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 123  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 124  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 125  1: Yes||2: No||B or -6: Not applicable
# 126  1: Yes||2: No||B or -6: Not applicable
# 127  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 128  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 129  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 130  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 131  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 132  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 133  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 134  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 135  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 136  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 137  1: Checked response||2: Did not check response||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 138  1: adequate||2: moderately inadequate||3: severely inadequate||B or -6: Not applicable
# 139  1: No listed conditions seen in or on the unit||B or -6: Not applicable||Blank or -9: Not reported
# 140  1: First occupants||2: Previously occupied||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 141  1900:2013: 1900-2013||B or -6: Not applicable
# 142  1: Gift or inheritance||2: Purchased||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 143  . or -9: Not reported||1:10: Rating (10 is best, 1 is worst)||B or -6: Not applicable||D or -7: Don't know||R or -8: Refused
# 144  1: Drilled||2: Dug||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 145  1: Only this home||2: 2 to 5||3: 6 to 9||4: 10 to 14||5: 15 or more||B or -6: Not applicable
# 146  1: Yes||2: No||B or -6: Not applicable||D or -7: Don't know||R or -8: Refused
# 147  1: Yes||2: No||B or -6: Not applicable||D or -7: Don't know||R or -8: Refused
# 148  1: Yes||2: No||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused
# 149  1: Public or private water system||2: Individual well||3: Spring||4: Cistern||5: Stream or lake||6: Commercial bottled water||7: Other; SPECIFY||B or -6: Not applicable||Blank or -9: Not reported||D or -7: Don't know||R or -8: Refused

# %% [markdown]
# ### Question 1
#
# Create exploratory table(s) and/or visualization(s) to check the data
# and help make modelling choices. These need not be very polished.
#
# ### Question 2
#
# What model will you use for prediction and why you
# did you choose this model?
#
# ### Question 3
#
# Briefly describe how you chose any regularization and other parameters
# in your model.
#
# ### Question 4
#
# What have you done to avoid overfitting?
#
# ### Question 5
#
# Create a visualization to help evaluate of your model. This
# visualization can be part of your answer to questions 2-4 or it
# can simply summarize your model's predictive accuracy.
#
# ### Question 6
#
# Create a function that returns the predictions of
# your model when given an identically-formatted pandas DataFrame
# (created from an identically formatted csv file by pd.read_csv)
# with all the same variables. Your function should not refit your model on
# the evaluation sample.
